# %%
# %run run_01-replace_where_for_ac_text_parser-question-a-f.py
# Out:
# Question 1
#
# Stem 1. On page 3, when the author mentions the possibility of people turning into puritans, she is using this word to refer to people who
#
#
#
# A. lived a long time ago
#
#
#
# B. rarely make a mistake
#
#
#
# C. are serious and reserved
#
#
#
# D. dress in plain and dark clothing
#
#
#
# EndQ
#
#
#
# Question 2
#
# Stem 2. At the beginning of the essay, the author suggests that people are so concerned with having fun that they
#
#
#
# A. try to find fun in all their experiences
#
#
#
# B. spend a lot of money trying to have fun
#
#
#
# C. join groups to learn how to have fun
#
#
#
# D. avoid new experiences that may not be fun
#
#
#
# EndQ
#
#
#
# Question 3
#
# Stem 3. What is the author's point about big occasions like holidays?
#
#
#
# A. They go by too quickly to be enjoyed.
#
#
#
# B. They are not as much fun as people expect them to be.
#
#
#
# C. They have become too centered around money.
#
#
#
# D. They help us to appreciate the important events in life.
# ...

# %%
# %run run_02.1-semi_structured_ac_text_parser-passage.py
# Out:
# 0 Reading Passage
#  [1]-Page 3
#
#
# 1 CONTENT
#
#
#
# FUN
#
#
#
# by Suzanne Britt Jordan
#
#
#
# Fun is hard to have.
#
# Fun is a rare jewel.
#
# Somewhere along the line people got the modern idea that fun was there for the asking, that people deserved fun, that if we didn't have a little fun every day we would turn into (sakes alive!) puritans.
#
# "Was it fun?" became the question that overshadowed all other questions: good questions like: Was it moral? Was it kind? Was it honest? Was it beneficial? Was it generous? Was it necessary? And (my favorite) was it selfless?
#
# When the pleasure got to be the main thing, the fun fetish was sure to follow. Everything was supposed to be fun. If it wasn't fun, then we were going to make it fun, or else.
#
# ...

# %%
# %run run_02.2-semi_structured_ac_text_parser-question.py
# Out:
# C:\Users\Sano.Makoto\Documents\Research\plimac\3.00\Tools\semi_structured_ac_text_parser.py:30: FutureWarning: from_items is deprecated. Please use DataFrame.from_dict(dict(items), ...) instead. DataFrame.from_dict(OrderedDict(items)) may be used to preserve the key order.
#   orient='index', columns=col_names)
# 0 Question
#  1
#
# 1 Stem
#  1. On page 3, when the author mentions the possibility of people turning into puritans, she is using this word to refer to people who
#
#
# 2 A.
#  lived a long time ago
#
#
# 3 B.
#  rarely make a mistake
#
#
# 4 C.
#  are serious and reserved
#
#
# 5 D.
#  dress in plain and dark clothing
#
#
# 6 EndQ
#
#
#
# 0 Question
#  2
#
# 1 Stem
#  2. At the beginning of the essay, the author suggests that people are so concerned with having fun that they
#
#
# 2 A.
#  try to find fun in all their experiences
#
#
# 3 B.
#  spend a lot of money trying to have fun
#
#
# 4 C.
#  join groups to learn how to have fun
#
#
# 5 D.
# ...

# %%
# %run run_03_ac_column_serializer.py
# Out:
#   Pre_Col_Name                                            Content  Question#
# 0         Stem  1. On page 3, when the author mentions the pos...          1
# 1            A                              lived a long time ago          1
# 2            B                              rarely make a mistake          1
# 3            C                           are serious and reserved          1
# 4            D                   dress in plain and dark clothing          1
#   Pre_Col_Name                                            Content  Question#
# 0         Stem  2. At the beginning of the essay, the author s...          2
# 1            A           try to find fun in all their experiences          2
# 2            B            spend a lot of money trying to have fun          2
# 3            C               join groups to learn how to have fun          2
# 4            D          avoid new experiences that may not be fun          2
# ...

# %%
# %run run_04_1_ac_pos_tagger_lemmatizer_synset.py
# Out:
# [('1', 'CD'), ('.', '.'), ('On', 'IN'), ('page', 'NN'), ('3', 'CD'), (',', ','), ('when', 'WRB'), ('the', 'DT'), ('author', 'NN'), ('mentions', 'VBZ'), ('the', 'DT'), ('possibility', 'NN'), ('of', 'IN'), ('people', 'NNS'), ('turning', 'VBG'), ('into', 'IN'), ('puritans', 'NNS'), (',', ','), ('she', 'PRP'), ('is', 'VBZ'), ('using', 'VBG'), ('this', 'DT'), ('word', 'NN'), ('to', 'TO'), ('refer', 'VB'), ('to', 'TO'), ('people', 'NNS'), ('who', 'WP')]
# [('lived', 'VBD'), ('a', 'DT'), ('long', 'JJ'), ('time', 'NN'), ('ago', 'IN')]
# [('rarely', 'RB'), ('make', 'VB'), ('a', 'DT'), ('mistake', 'NN')]
# [('are', 'VBP'), ('serious', 'JJ'), ('and', 'CC'), ('reserved', 'VBD')]
# [('dress', 'NN'), ('in', 'IN'), ('plain', 'NN'), ('and', 'CC'), ('dark', 'NN'), ('clothing', 'NN')]
# ...
